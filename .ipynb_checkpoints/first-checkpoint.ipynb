# %% [markdown]
# **Author:**
#
# Shivam Yadav

# %% [markdown]
# ## Table of Contents
#
# 1. [Introduction](#introduction)
# 2. [Importing and Installing required libraries](#import)
# 3. [Data Visualization and Preprocessing](#visual)
# 4. [Text Preprocessing](#text)
# 3. [Remove Duplicate Records](#remove-duplicate-records)
# 4. [Remove Records with Profanities](#remove-records-with-profanities)
# 5. [Identify Incoherent or Grammatically Incorrect Text](#identify-incoherent-or-grammatically-incorrect-text)
# 6. [Data Preprocessing for Text Classification](#data-preprocessing-for-text-classification)
# 7. [Model Selection and Training](#model-selection-and-training)
# 8. [Conclusion](#conclusion)

# %% [markdown]
# # Introduction <a name="introduction"></a>

# %% [markdown]
# # Assignment: Text Classification Project
#
# Welcome to this exciting journey of natural language processing (NLP) and text classification. In this assignment, we will embark on a mission to preprocess and classify textual data, from the very basics to advanced techniques.
#
# ## Assignment Overview
#
# This project is designed to showcase my skills in data preprocessing, text classification, and model training. I will be working with a dataset of text and emotions, cleaning the data, identifying incoherent text, and finally, building a powerful classification model.
#
# ## MY Mission
#
# 1. **Data Collection and Preprocessing:** We start with the fundamentals—collecting your data and preparing it for analysis.
#
# 2. **Remove Duplicate Records:** Clean data is crucial. Duplicate records can clutter our analysis. We'll learn to eliminate them.
#
# 3. **Remove Records with Profanities:** We'll ensure our text is clean and respectful by filtering out records with profanities.
#
# 4. **Identify Incoherent or Grammatically Incorrect Text:** Quality matters. We'll look at how to spot incoherent text and enhance its readability.
#
# 5. **Data Preprocessing for Text Classification:** Getting the data ready for model training. We'll tokenize, lowercase, remove stopwords, and more.
#
# 6. **Model Selection and Training:** The heart of our project. We'll choose a classification model and fine-tune it to achieve the best accuracy.
#
# 7. **Conclusion:** Summing up our achievements, you'll be well-prepared for the next phase of your NLP journey.
#
# ## My Challenge
#
# My goal is to complete each step with precision, document my work, and create a high-performance text classification model. This project will demonstrate my mastery of NLP concepts and hands-on skills.
#
# Get ready to transform text into knowledge, and let's embark on this thrilling journey!
#
# _Submission Deadline: October 18, 2023_

# %% [markdown]
# ## Importing and Installing required libraries <a name="import"></a>

# %%
import numpy as np
import pandas as pd
import string

import nltk
import spacy
import re
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %% [markdown]
# ### Importing the Dataset

# %% [markdown]
# - At first I am assuming you given me row data
# - So that I do every step which is necessary

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#                                                 Text Classification
# 0                            i didnt feel humiliated        sadness
# 1  i can go from feeling so hopeless to so damned...        sadness
# 2   im grabbing a minute to post i feel greedy wrong          anger
# 3  i am ever feeling nostalgic about the fireplac...           love
# 4                               i am feeling grouchy          anger

# %%
# basic things
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18001 entries, 0 to 18000
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Text            18001 non-null  object
#  1   Classification  18001 non-null  object
# dtypes: object(2)
# memory usage: 281.4+ KB

# %%
backup = df.copy()

# %%
df.describe()
# Out:
#                                                      Text Classification
# count                                               18001          18001
# unique                                              17958              6
# top     i was so stubborn and that it took you getting...            joy
# freq                                                    2           6058

# %%
df.isnull().sum()
# Out:
# Text              0
# Classification    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df['Classification'].unique()
# Out:
# array(['sadness', 'anger', 'love', 'surprise', 'fear', 'joy'],
#       dtype=object)

# %% [markdown]
# ## Data Visualization and Preprocessing<a name='visual'></a>

# %%
# Do some visualization to know about the data like how it look
# I use plotly because it already have advanced inbuilt things 
# even though you can use seaborn or matplotlib

# %%
fig = px.histogram(df, x='Classification', color='Classification')
fig.update_layout(
    height=400,
    width=600,
)
fig.update_traces(marker=dict(line=dict(width=2)))
fig.show()
# Out:
# <div>                            <div id="688295cd-dd48-4fd6-b989-46f2e09dbf01" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("688295cd-dd48-4fd6-b989-46f2e09dbf01")) {                    Plotly.newPlot(                        "688295cd-dd48-4fd6-b989-46f2e09dbf01",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Classification=%{x}<br>count=%{y}<extra></extra>","legendgroup":"sadness","marker":{"color":"#636efa","pattern":{"shape":""},"line":{"width":2}},"name":"sadness","offsetgroup":"sadness","orientation":"v","showlegend":true,"x":["sadness","sadness","sadness","sadness","sadness","sadness","sadness","sadness","sadness","sadness","sadness","sadness","sadness","sadness","sadness","sadness","sadness","sadness","s
# ...

# %%
# length of text

# %%
df['Text_length'] = df['Text'].astype(str).apply(len)

# %%
df['Text_word_count'] = df['Text'].apply(lambda x: len(str(x).split()))

# %%
df.head()
# Out:
#                                                 Text Classification  \
# 0                            i didnt feel humiliated        sadness
# 1  i can go from feeling so hopeless to so damned...        sadness
# 2   im grabbing a minute to post i feel greedy wrong          anger
# 3  i am ever feeling nostalgic about the fireplac...           love
# 4                               i am feeling grouchy          anger
#
#    Text_length  Text_word_count
# 0           23                4
# 1          108               21
# 2           48               10
# 3           92               18
# 4           20                4

# %%
sns.histplot(df['Text_length'], kde='True')
plt.xlim([0, 512])
plt.xlabel('Text Length')
# Out:
# Text(0.5, 0, 'Text Length')

# %% [markdown]
# #### The histogram above shows that the length of the tweet ranges from around 2 to 300 characters.

# %%
sns.boxplot(data=df, x="Classification", y="Text_word_count")
# Out:
# <Axes: xlabel='Classification', ylabel='Text_word_count'>

# %% [markdown]
# - Most of the Text have an average of 15 words.
# - Also, all the Text appear to have the more or less the same length.

# %% [markdown]
# #### Creating a column with label names.

# %%
# labels_dict = {0:'sadness', 1:'joy', 2:'love', 3:'anger', 4:'fear', 5:'surprise'}

# df['label'].map(labels_dict)

# %% [markdown]
# ## Text Preprocessing <a name='text'></a>

# %%
# convert text into lower case
df['Text'] = df['Text'].str.lower()

# %%
# remove any tags if present

def remove_html_tags(text):
    pattern = re.compile('<.*?>')
    return pattern.sub(r'', text)

# %%
df['Text'] = df['Text'].apply(remove_html_tags)

# %%
# remove urls
def remove_url(text):
    pattern = re.compile(r'https?://\S+|www.\S+')
    return pattern.sub('r', text)

# %%
df['Text'] = df['Text'].apply(remove_url)
